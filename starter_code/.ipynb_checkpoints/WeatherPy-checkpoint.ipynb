# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:

        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.001)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Bathsheba
# Processing Record 2 | Mataura
# Processing Record 3 | Albany
# City not found. Skipping...
# Processing Record 4 | Bratsk
# Processing Record 5 | Esperance
# City not found. Skipping...
# Processing Record 6 | Sorland
# Processing Record 7 | Koshurnikovo
# Processing Record 8 | Sioux Lookout
# Processing Record 9 | Provideniya
# Processing Record 10 | Camopi
# Processing Record 11 | Rikitea
# City not found. Skipping...
# Processing Record 12 | Bagdarin
# Processing Record 13 | Barrow
# Processing Record 14 | Lata
# Processing Record 15 | Nouadhibou
# City not found. Skipping...
# Processing Record 16 | Cayenne
# Processing Record 17 | Bambous Virieux
# City not found. Skipping...
# Processing Record 18 | Mogok
# Processing Record 19 | Hobart
# Processing Record 20 | Hithadhoo
# Processing Record 21 | San Patricio
# Processing Record 22 | Gweta
# Processing Record 23 | Port Alfred
# Processing Record 24 | Kapaa
# Processing Record 25 | Dunedin
# Processing Record 26 | Kamenka
# Processing Record 27 | Vaini
# Processing Record 28 | Tuktoyaktuk
# Processing Record 29 | Mar del Plata
# Processing Record 30 | Kruisfontein
# Processing Record 31 | Hami
# Processing Record 32 | Saskylakh
# Processing Record 33 | Matelica
# Processing Record 34 | Cap Malheureux
# Processing Record 35 | Roald
# Processing Record 36 | Georgetown
# Processing Record 37 | Fort Walton Beach
# Processing Record 38 | Lebu
# Processing Record 39 | Biak
# Processing Record 40 | Lasa
# Processing Record 41 | Batemans Bay
# City not found. Skipping...
# Processing Record 42 | Iqaluit
# Processing Record 43 | Yellowknife
# Processing Record 44 | Nabire
# Processing Record 45 | Ancud
# Processing Record 46 | Harindanga
# Processing Record 47 | Bubaque
# Processing Record 48 | Puksoozero
# Processing Record 49 | Hilo
# Processing Record 50 | Marawi
# Processing Record 51 | Ribeira Grande
# Processing Record 52 | Rocha
# Processing Record 53 | Pak Phanang
# Processing Record 54 | Matamoros
# City not found. Skipping...
# Processing Record 55 | Cape Town
# Processing Record 56 | Honiara
# Processing Record 57 | Progreso
# Processing Record 58 | Lagoa
# Processing Record 59 | Tasiilaq
# Processing Record 60 | Olinda
# Processing Record 61 | Ornskoldsvik
# Processing Record 62 | Punta Arenas
# Processing Record 63 | Katsuura
# Processing Record 64 | Tucumcari
# Processing Record 65 | Bethel
# Processing Record 66 | Mahebourg
# Processing Record 67 | New Norfolk
# Processing Record 68 | Lima
# Processing Record 69 | Tuatapere
# City not found. Skipping...
# Processing Record 70 | Ponta do Sol
# Processing Record 71 | Busselton
# Processing Record 72 | Atuona
# Processing Record 73 | Kailua
# Processing Record 74 | Arraial do Cabo
# City not found. Skipping...
# Processing Record 75 | Vanavara
# Processing Record 76 | Jamestown
# Processing Record 77 | Norman Wells
# Processing Record 78 | Pevek
# Processing Record 79 | Broome
# Processing Record 80 | Portland
# Processing Record 81 | Ahipara
# City not found. Skipping...
# Processing Record 82 | Avarua
# Processing Record 83 | Mehamn
# Processing Record 84 | Ushuaia
# City not found. Skipping...
# Processing Record 85 | Saint-Philippe
# City not found. Skipping...
# Processing Record 86 | College
# Processing Record 87 | Venice
# Processing Record 88 | Praia da Vitoria
# City not found. Skipping...
# Processing Record 89 | Kaitangata
# Processing Record 90 | Carnarvon
# Processing Record 91 | Bluff
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 92 | Novaya Igirma
# Processing Record 93 | Ostrovnoy
# Processing Record 94 | Borujerd
# Processing Record 95 | Labuhan
# Processing Record 96 | Cidreira
# Processing Record 97 | Gat
# Processing Record 98 | Victoria
# Processing Record 99 | Anaconda
# Processing Record 100 | Umm Kaddadah
# Processing Record 101 | Thompson
# Processing Record 102 | Flinders
# Processing Record 103 | Aksu
# Processing Record 104 | Dikson
# Processing Record 105 | Lompoc
# Processing Record 106 | Constitucion
# Processing Record 107 | Abu Kamal
# City not found. Skipping...
# Processing Record 108 | Bolobo
# Processing Record 109 | Kindu
# Processing Record 110 | Coahuayana
# Processing Record 111 | Linxia
# Processing Record 112 | Pilar
# Processing Record 113 | Cherskiy
# Processing Record 114 | Hermanus
# Processing Record 115 | Narsaq
# Processing Record 116 | Verkhnyaya Maksakovka
# Processing Record 117 | Saint-Augustin
# Processing Record 118 | Nizhniy Odes
# Processing Record 119 | Vestmanna
# Processing Record 120 | Wageningen
# Processing Record 121 | Yima
# Processing Record 122 | Sisimiut
# Processing Record 123 | Nortelandia
# City not found. Skipping...
# Processing Record 124 | Butaritari
# Processing Record 125 | Souillac
# Processing Record 126 | Phulji
# Processing Record 127 | High Prairie
# Processing Record 128 | Marathon
# Processing Record 129 | Yining
# City not found. Skipping...
# Processing Record 130 | Bambanglipuro
# Processing Record 131 | Necochea
# Processing Record 132 | Saint George
# Processing Record 133 | Hambantota
# City not found. Skipping...
# Processing Record 134 | Kodiak
# Processing Record 135 | Inhambane
# Processing Record 136 | Acajutla
# Processing Record 137 | Vila Franca do Campo
# Processing Record 138 | Muskegon
# Processing Record 139 | Kasongo-Lunda
# Processing Record 140 | Vao
# Processing Record 141 | Diglur
# Processing Record 142 | Sambava
# Processing Record 143 | Husavik
# Processing Record 144 | Tura
# Processing Record 145 | Ilulissat
# City not found. Skipping...
# Processing Record 146 | Nanortalik
# Processing Record 147 | Sao Filipe
# Processing Record 148 | Berlevag
# Processing Record 149 | Saint Pete Beach
# Processing Record 150 | Oranjemund
# City not found. Skipping...
# Processing Record 151 | Ngaoundere
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 152 | Hovd
# Processing Record 153 | Clyde River
# Processing Record 154 | Makakilo City
# Processing Record 155 | Puerto Ayora
# Processing Record 156 | Iranshahr
# Processing Record 157 | Palmer
# Processing Record 158 | Yidu
# Processing Record 159 | Flin Flon
# Processing Record 160 | Pokhara
# Processing Record 161 | Finschhafen
# City not found. Skipping...
# Processing Record 162 | Coihaique
# City not found. Skipping...
# Processing Record 163 | Walvis Bay
# Processing Record 164 | Road Town
# Processing Record 165 | Bo Rai
# Processing Record 166 | Qasigiannguit
# Processing Record 167 | Solton
# Processing Record 168 | Upernavik
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 169 | Zhangzhou
# Processing Record 170 | Termez
# Processing Record 171 | Tsumeb
# Processing Record 172 | Kavieng
# Processing Record 173 | Tigil
# Processing Record 174 | Andra
# Processing Record 175 | Port Hueneme
# Processing Record 176 | Highview
# Processing Record 177 | Balad
# Processing Record 178 | Ewo
# Processing Record 179 | Tiksi
# Processing Record 180 | Nome
# Processing Record 181 | Tolaga Bay
# Processing Record 182 | La Baneza
# City not found. Skipping...
# Processing Record 183 | Vanimo
# Processing Record 184 | Swellendam
# Processing Record 185 | Chuy
# Processing Record 186 | Khatanga
# Processing Record 187 | Durban
# Processing Record 188 | Longyearbyen
# Processing Record 189 | Klaksvik
# Processing Record 190 | Kahului
# Processing Record 191 | Okhotsk
# Processing Record 192 | Mogzon
# Processing Record 193 | Chokurdakh
# City not found. Skipping...
# Processing Record 194 | Jalu
# Processing Record 195 | Suraabad
# Processing Record 196 | San Quintin
# Processing Record 197 | Bredasdorp
# Processing Record 198 | Luganville
# Processing Record 199 | Nara
# City not found. Skipping...
# Processing Record 200 | Akdagmadeni
# Processing Record 201 | Manzanares
# Processing Record 202 | Tera
# Processing Record 203 | Zhigansk
# Processing Record 204 | East London
# Processing Record 205 | Male
# Processing Record 206 | Tamasane
# Processing Record 207 | Den Helder
# Processing Record 208 | Hasaki
# Processing Record 209 | Raudeberg
# Processing Record 210 | Rio Branco
# Processing Record 211 | Nishihara
# Processing Record 212 | Meulaboh
# Processing Record 213 | Aykhal
# Processing Record 214 | Brae
# Processing Record 215 | Skibbereen
# City not found. Skipping...
# Processing Record 216 | Gouyave
# City not found. Skipping...
# Processing Record 217 | Kashan
# Processing Record 218 | Muros
# Processing Record 219 | Sao Joao da Barra
# Processing Record 220 | Cabo San Lucas
# Processing Record 221 | North Bend
# Processing Record 222 | Guerrero Negro
# Processing Record 223 | Sarangani
# Processing Record 224 | Kathu
# Processing Record 225 | Three Hills
# Processing Record 226 | Xichang
# Processing Record 227 | Bilibino
# Processing Record 228 | Castro
# Processing Record 229 | Port Elizabeth
# Processing Record 230 | Tabou
# City not found. Skipping...
# Processing Record 231 | Vila Velha
# Processing Record 232 | Tevriz
# Processing Record 233 | Ossora
# Processing Record 234 | Lavrentiya
# Processing Record 235 | Nanning
# Processing Record 236 | Yulara
# Processing Record 237 | Dosso
# Processing Record 238 | Pacific Grove
# Processing Record 239 | Atyashevo
# Processing Record 240 | Mbeya
# Processing Record 241 | Levelland
# City not found. Skipping...
# Processing Record 242 | Teknaf
# Processing Record 243 | Itajuipe
# Processing Record 244 | Mpika
# Processing Record 245 | Aranos
# City not found. Skipping...
# Processing Record 246 | Merrill
# Processing Record 247 | Rindal
# Processing Record 248 | Ereymentau
# Processing Record 249 | Malanje
# Processing Record 250 | Santa Lucia
# Processing Record 251 | Mareeba
# Processing Record 252 | Svetlaya
# Processing Record 253 | Pleasanton
# City not found. Skipping...
# Processing Record 254 | Glace Bay
# Processing Record 255 | Liverpool
# Processing Record 256 | Dingle
# Processing Record 257 | Qaqortoq
# City not found. Skipping...
# Processing Record 258 | Orlik
# Processing Record 259 | Fortuna
# Processing Record 260 | Kolyvan
# Processing Record 261 | Zatoka
# Processing Record 262 | Ginir
# Processing Record 263 | Savannah Bight
# Processing Record 264 | Qaanaaq
# Processing Record 265 | Kautokeino
# Processing Record 266 | Codrington
# Processing Record 267 | Jiwani
# Processing Record 268 | Prainha
# Processing Record 269 | Beloha
# Processing Record 270 | Riberalta
# Processing Record 271 | Agadez
# Processing Record 272 | Yangshan
# Processing Record 273 | Shambu
# Processing Record 274 | Visby
# Processing Record 275 | Mayo
# Processing Record 276 | Mount Gambier
# Processing Record 277 | Bonavista
# Processing Record 278 | Tocopilla
# Processing Record 279 | Tawang
# City not found. Skipping...
# Processing Record 280 | San Angelo
# Processing Record 281 | Nikolskoye
# Processing Record 282 | San Cristobal
# Processing Record 283 | Beckley
# Processing Record 284 | Madimba
# City not found. Skipping...
# Processing Record 285 | Mayor Pablo Lagerenza
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 286 | Margate
# Processing Record 287 | Vestmannaeyjar
# Processing Record 288 | Pipri
# Processing Record 289 | Chicontepec
# Processing Record 290 | Porto Walter
# City not found. Skipping...
# Processing Record 291 | Belaya Gora
# Processing Record 292 | Ratnagiri
# Processing Record 293 | Dutse
# Processing Record 294 | Ambatondrazaka
# Processing Record 295 | Soure
# Processing Record 296 | Moses Lake
# Processing Record 297 | Alice Springs
# Processing Record 298 | Kidal
# Processing Record 299 | Lanzhou
# Processing Record 300 | Obanazawa
# Processing Record 301 | Ampanihy
# Processing Record 302 | Mackenzie
# City not found. Skipping...
# Processing Record 303 | Quincy
# Processing Record 304 | Shakhtinsk
# Processing Record 305 | Quatre Cocos
# Processing Record 306 | Chenghai
# Processing Record 307 | Zwedru
# Processing Record 308 | Geraldton
# Processing Record 309 | Inta
# Processing Record 310 | Gwadar
# Processing Record 311 | Kewanee
# Processing Record 312 | Santiago
# Processing Record 313 | Campos
# Processing Record 314 | Magrath
# Processing Record 315 | Petrozavodsk
# Processing Record 316 | Pringsewu
# City not found. Skipping...
# Processing Record 317 | Marsaxlokk
# Processing Record 318 | Kutum
# Processing Record 319 | Bagotville
# Processing Record 320 | Luderitz
# Processing Record 321 | Osoyoos
# City not found. Skipping...
# Processing Record 322 | Riyadh
# Processing Record 323 | Deputatskiy
# Processing Record 324 | Lufilufi
# Processing Record 325 | Rawson
# Processing Record 326 | Huarmey
# Processing Record 327 | Aquiraz
# Processing Record 328 | Grimshaw
# Processing Record 329 | Jurm
# Processing Record 330 | Isangel
# Processing Record 331 | Talnakh
# Processing Record 332 | Batagay-Alyta
# Processing Record 333 | Sidi Ali
# Processing Record 334 | Ende
# Processing Record 335 | Valley City
# Processing Record 336 | Whitianga
# Processing Record 337 | Sinnamary
# City not found. Skipping...
# Processing Record 338 | Tornio
# Processing Record 339 | Nemuro
# Processing Record 340 | Salta
# Processing Record 341 | Beringovskiy
# Processing Record 342 | Vardo
# Processing Record 343 | Alofi
# City not found. Skipping...
# Processing Record 344 | Bukachacha
# City not found. Skipping...
# Processing Record 345 | Kurchum
# Processing Record 346 | Fushe-Kruje
# Processing Record 347 | Port-Cartier
# Processing Record 348 | Saint Anthony
# Processing Record 349 | Lorengau
# Processing Record 350 | Vallenar
# Processing Record 351 | Nha Trang
# Processing Record 352 | Bekhtery
# City not found. Skipping...
# Processing Record 353 | Harper
# Processing Record 354 | Volga
# Processing Record 355 | High Level
# Processing Record 356 | Klyuchi
# City not found. Skipping...
# Processing Record 357 | Porto Novo
# Processing Record 358 | Araouane
# Processing Record 359 | Komsomolskiy
# City not found. Skipping...
# Processing Record 360 | Chalons-en-Champagne
# Processing Record 361 | General Roca
# Processing Record 362 | Bandarbeyla
# City not found. Skipping...
# Processing Record 363 | Vostok
# Processing Record 364 | Havelock
# City not found. Skipping...
# Processing Record 365 | Banjar
# Processing Record 366 | Batticaloa
# Processing Record 367 | Aguas Formosas
# Processing Record 368 | Oksfjord
# Processing Record 369 | Christchurch
# City not found. Skipping...
# Processing Record 370 | Sept-Iles
# Processing Record 371 | Kavaratti
# City not found. Skipping...
# Processing Record 372 | Frontera
# Processing Record 373 | Pombas
# Processing Record 374 | Seoul
# Processing Record 375 | Ekangala
# Processing Record 376 | Gediz
# City not found. Skipping...
# Processing Record 377 | Mitsamiouli
# Processing Record 378 | Tupelo
# Processing Record 379 | Jumla
# Processing Record 380 | Nelson Bay
# Processing Record 381 | Wainwright
# Processing Record 382 | Sangmelima
# Processing Record 383 | Swan River
# Processing Record 384 | Colquechaca
# Processing Record 385 | Iskateley
# City not found. Skipping...
# Processing Record 386 | Chengzihe
# Processing Record 387 | Point Fortin
# Processing Record 388 | Half Moon Bay
# Processing Record 389 | San Andres
# Processing Record 390 | Awka
# Processing Record 391 | Sitka
# Processing Record 392 | Briancon
# Processing Record 393 | Khvastovichi
# Processing Record 394 | Sumbe
# City not found. Skipping...
# Processing Record 395 | Ayna
# Processing Record 396 | Usinsk
# Processing Record 397 | Aleksandrov Gay
# Processing Record 398 | Koson
# Processing Record 399 | Tirlyanskiy
# Processing Record 400 | Siparia
# City not found. Skipping...
# Processing Record 401 | Mana
# Processing Record 402 | Ulladulla
# Processing Record 403 | Freeport
# Processing Record 404 | Port Hedland
# Processing Record 405 | Pavilosta
# Processing Record 406 | Pangnirtung
# Processing Record 407 | Sajkas
# Processing Record 408 | Antalaha
# Processing Record 409 | Jelling
# City not found. Skipping...
# Processing Record 410 | Holetown
# Processing Record 411 | Siniscola
# Processing Record 412 | Eucaliptus
# Processing Record 413 | Kununurra
# City not found. Skipping...
# Processing Record 414 | Placido de Castro
# Processing Record 415 | Badarwas
# Processing Record 416 | Itagi
# Processing Record 417 | Hazorasp
# Processing Record 418 | Bela Vista de Goias
# City not found. Skipping...
# Processing Record 419 | Leningradskiy
# Processing Record 420 | Maryborough
# Processing Record 421 | Touros
# City not found. Skipping...
# Processing Record 422 | Anadyr
# Processing Record 423 | Wloclawek
# Processing Record 424 | Texistepeque
# Processing Record 425 | Pochutla
# City not found. Skipping...
# Processing Record 426 | Almaty
# Processing Record 427 | Puerto Quijarro
# Processing Record 428 | Kalmunai
# Processing Record 429 | Samfya
# Processing Record 430 | Carauari
# Processing Record 431 | Etchojoa
# Processing Record 432 | Caravelas
# Processing Record 433 | Kuchera
# Processing Record 434 | Nampula
# Processing Record 435 | Sola
# Processing Record 436 | Hamilton
# Processing Record 437 | Northam
# Processing Record 438 | Namibe
# Processing Record 439 | Guigue
# Processing Record 440 | Shestakovo
# Processing Record 441 | Cockburn Town
# Processing Record 442 | Borinskoye
# Processing Record 443 | Nosy Varika
# Processing Record 444 | Torbay
# Processing Record 445 | Pacora
# Processing Record 446 | Zambezi
# Processing Record 447 | Saldanha
# Processing Record 448 | Pitimbu
# Processing Record 449 | Lewiston
# Processing Record 450 | Airai
# Processing Record 451 | Sobolevo
# Processing Record 452 | Faanui
# Processing Record 453 | Rio Gallegos
# Processing Record 454 | Hobyo
# City not found. Skipping...
# Processing Record 455 | Luebo
# Processing Record 456 | Mogadishu
# Processing Record 457 | Mesto Albrechtice
# Processing Record 458 | Helsinki
# Processing Record 459 | Mayumba
# Processing Record 460 | Zhangye
# Processing Record 461 | Smirnykh
# Processing Record 462 | Leshukonskoye
# Processing Record 463 | Asenovgrad
# Processing Record 464 | Palestine
# Processing Record 465 | Haines Junction
# Processing Record 466 | Rongcheng
# Processing Record 467 | Casa Nova
# Processing Record 468 | Millau
# Processing Record 469 | Upata
# Processing Record 470 | Port Hawkesbury
# Processing Record 471 | Urusha
# Processing Record 472 | Chernenko
# Processing Record 473 | Ponta Delgada
# City not found. Skipping...
# Processing Record 474 | Huangchuan
# Processing Record 475 | Jacareacanga
# Processing Record 476 | Neon Petritsion
# Processing Record 477 | Basco
# Processing Record 478 | Angoche
# Processing Record 479 | Ploemeur
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 480 | Tazovskiy
# Processing Record 481 | Sunrise Manor
# Processing Record 482 | Tateyama
# Processing Record 483 | Dalbandin
# Processing Record 484 | Davila
# Processing Record 485 | Pisco
# Processing Record 486 | Whyalla
# Processing Record 487 | Goderich
# Processing Record 488 | Williston
# Processing Record 489 | Samarai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 490 | Krasnyy Chikoy
# Processing Record 491 | Itatiaia
# Processing Record 492 | Bom Jesus
# Processing Record 493 | Altamira
# Processing Record 494 | Lokomotivnyy
# Processing Record 495 | Along
# Processing Record 496 | Augusta
# Processing Record 497 | Immokalee
# Processing Record 498 | Chulman
# Processing Record 499 | Kuching
# Processing Record 500 | Wicklow
# Processing Record 501 | Itarema
# Processing Record 502 | Ilembo
# Processing Record 503 | Broken Hill
# Processing Record 504 | Mutoko
# Processing Record 505 | Port Augusta
# Processing Record 506 | Juneau
# Processing Record 507 | Camacha
# Processing Record 508 | Baykit
# Processing Record 509 | Faya
# Processing Record 510 | Georgiyevka
# Processing Record 511 | Bilma
# Processing Record 512 | East Valencia
# City not found. Skipping...
# Processing Record 513 | Ugoofaaru
# Processing Record 514 | Port Blair
# Processing Record 515 | Haguenau
# Processing Record 516 | Nhulunbuy
# Processing Record 517 | Yenagoa
# Processing Record 518 | Glenwood Springs
# City not found. Skipping...
# Processing Record 519 | Bonoua
# Processing Record 520 | Meghraj
# Processing Record 521 | Roncesvalles
# City not found. Skipping...
# Processing Record 522 | Voi
# Processing Record 523 | Xining
# Processing Record 524 | Zheleznodorozhnyy
# Processing Record 525 | Gisborne
# Processing Record 526 | Santo Augusto
# Processing Record 527 | Valday
# Processing Record 528 | Lishui
# Processing Record 529 | Axim
# Processing Record 530 | Capoterra
# Processing Record 531 | Shimoda
# Processing Record 532 | Keokuk
# Processing Record 533 | Rumuruti
# Processing Record 534 | Formosa
# Processing Record 535 | Campos Belos
# City not found. Skipping...
# Processing Record 536 | Calvinia
# City not found. Skipping...
# Processing Record 537 | Kaeo
# City not found. Skipping...
# Processing Record 538 | Pachino
# City not found. Skipping...
# Processing Record 539 | Russell
# Processing Record 540 | Kamaishi
# Processing Record 541 | Naklo nad Notecia
# Processing Record 542 | Charleston
# Processing Record 543 | Itoman
# Processing Record 544 | Bud
# Processing Record 545 | Novovarshavka
# Processing Record 546 | Bani Walid
# Processing Record 547 | Saint-Louis
# Processing Record 548 | Pauini
# Processing Record 549 | Darhan
# Processing Record 550 | Ixtapa
# Processing Record 551 | San Policarpo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('output_data/cities.csv')

# Display data frame head 
weather_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-12f327b43954> in <module>
#       1 # Save data frame to CSV
# ----> 2 weather_data.to_csv('output_data/cities.csv')
#       3
#       4 # Display data frame head
#       5 weather_data.head()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
